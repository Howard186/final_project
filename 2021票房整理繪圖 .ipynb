# %% [markdown]
# ### Import 套件

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 導入資料並整理成dataframe

# %%
tw_df = pd.DataFrame()
us_df = pd.DataFrame()
total_df = pd.DataFrame()
for i in ["20_1228-0103","0104-0110","0111-0117","0118-0124","0125-0131","0201-0207","0208-0214","0215-0221","0222-0228","0301-0307","0308-0314","0315-0321","0322-0328","0329-0404","0405-0411","0412-0418","0419-0425","0426-0502","0503-0509","0510-0516","0517-0520","0712-0725","0726-0801","0802-0808","0809-0815","0816-0822","0823-0829","0830-0905","0906-0912","0913-0919","0920-0926","0927-1003","1004-1010","1011-1017","1018-1024","1025-1031","1101-1107","1108-1114","1115-1121","1122-1128","1129-1205","1206-1212","1213-1219","1220-1226","1220-1226", "1227-0102","22_0103-0109"]:
    taiwan_box = []
    us_box = []
    total_box = []
    with open("./boxoffice_json/" + i + ".json", "r",encoding="utf-8") as file:
        box_office = json.load(file)
    for j in range(len((box_office["list"]))):
        total_box.append(box_office["list"][j])
        if box_office["list"][j]["country"] == "中華民國" :
            taiwan_box.append(box_office["list"][j])
        elif box_office["list"][j]["country"] == "美國" :
            us_box.append(box_office["list"][j])
    total = pd.DataFrame(total_box)
    tw = pd.DataFrame(taiwan_box)
    us = pd.DataFrame(us_box)
    tw["week"] = i
    us["week"] = i
    total["week"] = i 
    tw["week_amount"] = tw["amounts"].sum()
    us["week_amount"] = us["amounts"].sum()
    total["week_amount"] = total["amounts"].sum()
    tw_df = tw_df.append(tw).reset_index().drop("index",axis=1)
    us_df = us_df.append(us).reset_index().drop("index",axis=1)
    total_df = total_df.append(total).reset_index().drop("index",axis=1)

# %%
total_df.to_csv("2021台灣票房.csv", encoding='utf_8_sig')
us_df.to_csv("2021美國片票房.csv", encoding='utf_8_sig')
tw_df.to_csv("2021國片票房.csv", encoding='utf_8_sig')

# %% [markdown]
# ### 分項總票房整理匯出

# %%
total = total_df[["week","week_amount"]]
tot = total.drop_duplicates(keep='first', inplace=False).reset_index().drop("index",axis=1)

us = us_df[["week","week_amount"]]
usa = us.drop_duplicates(keep='first', inplace=False).reset_index().drop("index",axis=1)

tw = tw_df[["week","week_amount"]]
taiwan = tw.drop_duplicates(keep='first', inplace=False).reset_index().drop("index",axis=1)

# %%
plt.figure(figsize=(50,10))
plt.plot(tot["week"], tot["week_amount"], 'black', label='Total')
plt.plot(taiwan["week"], taiwan["week_amount"], 'b', label='TW')
plt.plot(us["week"], us["week_amount"], 'r', label='USA')
plt.xlabel('Week')# 設定x軸標題 # 設定x軸label以及垂直顯示
plt.title('2021 Box office') # 設定圖表標題
plt.legend(loc = 'lower left')
plt.show()

# %%
plt.figure(figsize=(50,10))
plt.plot(taiwan["week"], taiwan["week_amount"], 'b', label='TW')
plt.plot(us["week"], us["week_amount"], 'r', label='USA')
plt.xlabel('Week')# 設定x軸標題 # 設定x軸label以及垂直顯示
plt.title('2021 Box office') # 設定圖表標題
plt.legend(loc = 'lower left')
plt.show()

# %%
tw_df[(tw_df["name"]== "靈語")].reset_index().drop("index",axis=1).to_csv("靈語.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "瀑布")].reset_index().drop("index",axis=1).to_csv("瀑布.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "複身犯")].reset_index().drop("index",axis=1).to_csv("複身犯.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "詭扯")].reset_index().drop("index",axis=1).to_csv("詭扯.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "當男人戀愛時")].reset_index().drop("index",axis=1).to_csv("當男人戀愛時.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "哭悲")].reset_index().drop("index",axis=1).to_csv("哭悲.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "青春弒戀")].reset_index().drop("index",axis=1).to_csv("青春弒戀.csv", encoding='utf_8_sig')

# %% [markdown]
# ### 2021台灣國片逐週票房整理匯出

# %%
tw_df[(tw_df["name"]== "迷失安狄")].reset_index().drop("index",axis=1).to_csv("迷失安狄.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "叱咤風雲")].reset_index().drop("index",axis=1).to_csv("叱咤風雲.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "哭悲")].reset_index().drop("index",axis=1).to_csv("哭悲.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "緝魂")].reset_index().drop("index",axis=1).to_csv("緝魂.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "角頭－浪流連")].reset_index().drop("index",axis=1).to_csv("角頭－浪流連.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "我沒有談的那場戀愛")].reset_index().drop("index",axis=1).to_csv("我沒有談的那場戀愛.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "跟你老婆去旅行")].reset_index().drop("index",axis=1).to_csv("跟你老婆去旅行.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "複身犯")].reset_index().drop("index",axis=1).to_csv("複身犯.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "當男人戀愛時")].reset_index().drop("index",axis=1).to_csv("當男人戀愛時.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "聽見歌 再唱")].reset_index().drop("index",axis=1).to_csv("聽見歌 再唱.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "轉彎之後......")].reset_index().drop("index",axis=1).to_csv("轉彎之後.......csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "期末考")].reset_index().drop("index",axis=1).to_csv("期末考.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "邪佞")].reset_index().drop("index",axis=1).to_csv("邪佞.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "靈語")].reset_index().drop("index",axis=1).to_csv("靈語.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "瀑布")].reset_index().drop("index",axis=1).to_csv("瀑布.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "青春弒戀")].reset_index().drop("index",axis=1).to_csv("青春弒戀.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "金錢男孩MONEYBOYS")].reset_index().drop("index",axis=1).to_csv("金錢男孩MONEYBOYS.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "月老")].reset_index().drop("index",axis=1).to_csv("月老.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "美國女孩")].reset_index().drop("index",axis=1).to_csv("美國女孩.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "詭祭")].reset_index().drop("index",axis=1).to_csv("詭祭.csv", encoding='utf_8_sig')
tw_df[(tw_df["name"]== "詭扯")].reset_index().drop("index",axis=1).to_csv("詭扯.csv", encoding='utf_8_sig')

# %% [markdown]
# ### 各部電影繪製逐周票房圖

# %%
from matplotlib.font_manager import FontProperties
my_font = FontProperties(fname="simhei-1.ttf")

# %%
fall = tw_df[(tw_df["name"]== "瀑布")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(fall['week'].values, fall['totalAmounts'].values, label='瀑布')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
andy = tw_df[(tw_df["name"]== "迷失安狄")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(andy['week'].values, andy['totalAmounts'].values, label='迷失安狄')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
racing = tw_df[(tw_df["name"]== "叱咤風雲")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(racing['week'].values, racing['totalAmounts'].values, label='叱咤風雲')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
cry = tw_df[(tw_df["name"]== "哭悲")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(cry['week'].values, cry['totalAmounts'].values, label='哭悲')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
soul = tw_df[(tw_df["name"]== "緝魂")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(soul['week'].values, soul['totalAmounts'].values, label='緝魂')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
love = tw_df[(tw_df["name"]== "我沒有談的那場戀愛")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(love['week'].values, love['totalAmounts'].values, label='我沒有談的那場戀愛')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
travel = tw_df[(tw_df["name"]== "跟你老婆去旅行")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(travel['week'].values, travel['totalAmounts'].values, label='跟你老婆去旅行')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
double = tw_df[(tw_df["name"]== "複身犯")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(double['week'].values, double['totalAmounts'].values, label='複身犯')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
man_love = tw_df[(tw_df["name"]== "當男人戀愛時")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(man_love['week'].values, man_love['totalAmounts'].values, label='當男人戀愛時')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
singing = tw_df[(tw_df["name"]== "聽見歌 再唱")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(18, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(singing['week'].values, singing['totalAmounts'].values, label='聽見歌 再唱')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
exam = tw_df[(tw_df["name"]== "期末考")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(exam['week'].values, exam['totalAmounts'].values, label='期末考')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
devil = tw_df[(tw_df["name"]== "邪佞")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(devil['week'].values, devil['totalAmounts'].values, label='邪佞')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
words = tw_df[(tw_df["name"]== "靈語")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(words['week'].values, words['totalAmounts'].values, label='靈語')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
young = tw_df[(tw_df["name"]== "青春弒戀")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(young['week'].values, young['totalAmounts'].values, label='青春弒戀')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
moneyboys = tw_df[(tw_df["name"]== "金錢男孩MONEYBOYS")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(moneyboys['week'].values, moneyboys['totalAmounts'].values, label='金錢男孩MONEYBOYS')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
us_girl = tw_df[(tw_df["name"]== "美國女孩")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(us_girl['week'].values, us_girl['totalAmounts'].values, label='美國女孩')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
trick = tw_df[(tw_df["name"]== "詭祭")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(trick['week'].values, trick['totalAmounts'].values, label='詭祭')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
bullshit = tw_df[(tw_df["name"]== "詭扯")].reset_index().drop("index",axis=1)
fig = plt.figure(figsize=(14, 8))
plt.tick_params(axis='x', labelsize=6)
ax = plt.axes()
ax.plot(bullshit['week'].values, bullshit['totalAmounts'].values, label='詭扯')
ax.set_title('票房累計', fontproperties=my_font)
ax.set_xlabel('週別', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()
